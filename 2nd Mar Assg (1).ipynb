# %% [markdown]
# # 2nd Mar Assg

# %% [markdown]
# # Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Ans) Matplotlib is a Python library for creating static, animated, and interactive visualizations in a variety of formats. It's widely used for data visualization and plotting. The library provides an object-oriented API for embedding plots into applications that use general-purpose GUI toolkits, such as Tkinter, wxPython, Qt, or GTK.
#
# The Pyplot module in Matplotlib is a collection of functions that make Matplotlib work like MATLAB. It provides a convenient way to create various types of plots. Here are five types of plots you can create using Pyplot:
#
# Line Plot:   plt.plot(x, y)
#
# Scatter Plot:  plt.scatter(x, y)
#
# Bar Plot:   plt.bar(x, height)
#
# Histogram:  plt.hist(data, bins)
#
# Pie Chart:  plt.pie(sizes, labels)

# %% [markdown]
# # Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %% [markdown]
# Ans) A scatter plot is a graph that displays individual data points in a two-dimensional space, with each point representing values of two variables. It's useful for visualizing relationships and patterns between the variables, often used to explore correlations or identify outliers.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %% [markdown]
# # Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %% [markdown]
# Ans) The subplot() function in Matplotlib is used to create multiple plots within the same figure. It allows you to arrange subplots in a grid, specifying the number of rows and columns, and then select a specific subplot to plot your data.

# %%
import matplotlib.pyplot as plt

# Create a 2x2 grid of subplots
plt.subplot(2, 2, 1)
plt.plot([1, 2, 3])

plt.subplot(2, 2, 2)
plt.scatter([4, 5, 6],[4.5,5,6],c='r')

plt.subplot(2, 2, 3)
plt.bar([7, 8, 9],[2,3,4])

plt.subplot(2, 2, 4)
plt.barh([10, 11, 12],[1,2,3])

plt.show()

# %% [markdown]
# # Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# Ans) A bar plot is a type of data visualization that represents categorical data with rectangular bars. Each bar's length or height corresponds to the value of the data it represents. Bar plots are commonly used to display and compare the values of different categories or groups.

# %%
import numpy as np
import matplotlib.pyplot as plt
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [markdown]
# Ans) A box plot, also known as a box-and-whisker plot, is a statistical visualization that provides a summary of the distribution of a dataset. It displays key statistical measures such as the median, quartiles, and potential outliers.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Create a box plot
plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'])
plt.title('Box Plot of Box1 and Box2')
plt.xlabel('Box')
plt.ylabel('Values')

# Show the plot
plt.show()
